# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = {'GPA': [3.0, 3.7, 3.3, 2.5, 4.0, 3.2, 3.9, 3.0], 'Hours Studied': [2, 8, 3, 1, 12, 7, 9, 5]}
df = pd.DataFrame(data, columns = ['GPA', 'Hours Studied'])
#df.shape #print the dataframe dimensions
#df prints the whole df
#df.head() prints just the 5 first entries of the df
df
#df.shape returns the matrix's dimensions

# %%
#Getting a linear regression consists of 3 different stages.
# 1. Analyzing the correlation and directionality of the data.
# 2. Estimating the model by fitting the line.
# 3. Evaluating the validity and usefulness of the model.

#Introduce data
data = {'GPA': [3.0, 3.7, 3.3, 2.5, 4.0, 3.2, 3.9, 3.0], 'Hours Studied': [2, 8, 3, 1, 12, 7, 9, 5]}
df = pd.DataFrame(data, columns = ['GPA', 'Hours Studied'])

#Split data into 2 sets: X & Y
X = df['Hours Studied'].values
#X = X[:, np.newaxis]
print(X)
print(Y)

Y = df['GPA'].values

regr = LinearRegression()
regr.fit(X, Y)

#X = np.array([3.0, 3.7, 3.3, 2.5, 4.0, 3.2, 3.9, 3.0])
#Y = np.array([2, 8, 3, 1, 12, 7, 9, 5])

#Draw the data in the graph in terms of dots
plt.scatter(X, Y, color='#f492fc', label='Data')

#Labels to axis
plt.xlabel('Hours Studied')
plt.ylabel('GPA')

lr = LinearRegression().fit(X, Y)

plt.plot(X, Y, color="#aaaaaa")

#plt.xticks(())
#plt.yticks(())

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

#print(diabetes_X)
# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2] #poner en una columna
#print(diabetes_X)
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20] #le resta los 20 ultimos
diabetes_X_test = diabetes_X[-20:]#le resta los 20 primeros 

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

print(diabetes_X)
print(diabetes_y)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# [[ 0.06169621]
#  [-0.05147406]
#  [ 0.04445121]
#  [-0.01159501]
#  [-0.03638469]
#  [-0.04069594]
#  [-0.04716281]
#  [-0.00189471]
#  [ 0.06169621]
#  [ 0.03906215]
#  [-0.08380842]
#  [ 0.01750591]
#  [-0.02884001]
#  [-0.00189471]
#  [-0.02560657]
#  [-0.01806189]
#  [ 0.04229559]
#  [ 0.01211685]
#  [-0.0105172 ]
#  [-0.01806189]
#  [-0.05686312]
#  [-0.02237314]
#  [-0.00405033]
#  [ 0.06061839]
#  [ 0.03582872]
#  [-0.01267283]
#  [-0.07734155]
#  [ 0.05954058]
#  [-0.02129532]
#  [-0.00620595]
#  [ 0.04445121]
#  [-0.06548562]
#  [ 0.12528712]
#  [-0.05039625]
#  [-0.06332999]
#  [-0.03099563]
#  [ 0.02289497]
#  [ 0.01103904]
#  [ 0.07139652]
#  [ 0.01427248]
#  [-0.00836158]
#  [-0.06764124]
#  [-0.0105172 ]
#  [-0.02345095]
#  [ 0.06816308]
#  [-0.03530688]
#  [-0.01159501]
#  [-0.0730303 ]
#  [-0.04177375]
#  [ 0.01427248]
#  [-0.00728377]
#  [ 0.0164281 ]
#  [-0.00943939]
#  [-0.01590626]
#  [ 0.0250506 ]
#  [-0.04931844]
#  [ 0.04121778]
#  [-0.06332999]
# ...
