# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pandas.core.arrays.sparse import SparseArray as _SparseArray
from sklearn import preprocessing
import statsmodels.api as sm

# %%
data = pd.read_csv(r'boise-weather-forecast-dataset.csv')
#df = pd.DataFrame(data, columns=['Name', 'Datetime', 'Temp Max', 'Temp Min', 'Temp', 'Feels like max', 'Feels like min' , 'Feels like' , 'Dew' , 'Humidity' , 'Precip' , 'Precip prob', 'Precip cover', 'Precip type', 'Snow' , 'Snow depth', 'Wind gust', 'Wind speed' , 'Wind dir', 'Sea level pressure', 'Cloud cover', 'Visibility', 'Solar radiation', 'Solar energy', 'UV index', 'Severe risk', 'Sunrise', 'Sunset' , 'Moon phase', 'Conditions', 'Description', 'Icon', 'Stations'])
#data
df = pd.DataFrame(data, columns=['name','datetime','tempmax','tempmin','temp','feelslikemax','feelslikemin','feelslike','dew','humidity','precip','precipprob','precipcover','preciptype','snow','snowdepth','windgust','windspeed','winddir','sealevelpressure','cloudcover','visibility','solarradiation','solarenergy','uvindex','severerisk','sunrise','sunset','moonphase','conditions','description','icon','stations', 'label'])

#df.columns
df.columns=['Name', 'Datetime', 'TempMax', 'TempMin', 'Temp', 'Feelslikemax', 'Feelslikemin' , 'Feelslike' , 'Dew' , 'Humidity' , 'Precip' , 'PrecipProb', 'PrecipCover', 'PrecipType', 'Snow' , 'SnowDepth', 'WindGust', 'WindSpeed' , 'WindDir', 'SeaLevelPressure', 'CloudCover', 'Visibility', 'SolarRadiation', 'SolarEnergy', 'UVIndex', 'SevereRisk', 'Sunrise', 'Sunset' , 'MoonPhase', 'Conditions', 'Description', 'Icon', 'Stations', 'Label']
#df.columns

#df
#df.insert(len(df.columns), "Label", '')
df
#Recorrer df y asignar 0 o 1 si ha llovido ese día
# Out:
#       Name Datetime  TempMax  TempMin  Temp  Feelslikemax  Feelslikemin  \
# 0    Boise   8/1/21     27.2     20.6  23.3          28.2          20.6
# 1    Boise   8/2/21     33.4     20.6  26.6          32.1          20.6
# 2    Boise   8/3/21     35.0     20.6  27.7          33.3          20.6
# 3    Boise   8/4/21     39.9     19.9  29.7          37.3          19.9
# 4    Boise   8/5/21     35.6     22.8  29.4          33.4          22.8
# ..     ...      ...      ...      ...   ...           ...           ...
# 361  Boise  7/28/22     39.3     21.7  31.1          36.9          21.7
# 362  Boise  7/29/22     40.0     21.1  31.2          37.0          21.1
# 363  Boise  7/30/22     39.4     21.6  31.4          36.2          21.6
# 364  Boise  7/31/22     41.1     23.7  32.2          37.8          23.7
# 365  Boise   8/1/22     38.8     23.7  31.5          36.2          23.7
#
#      Feelslike   Dew  Humidity  ...  UVIndex  SevereRisk              Sunrise  \
# ...

# %%
df = df.dropna(axis='columns')
df.isna().sum()
# Out:
# Name                0
# Datetime            0
# TempMax             0
# TempMin             0
# Temp                0
# Feelslikemax        0
# Feelslikemin        0
# Feelslike           0
# Dew                 0
# Humidity            0
# Precip              0
# PrecipProb          0
# PrecipCover         0
# Snow                0
# SnowDepth           0
# WindSpeed           0
# WindDir             0
# SeaLevelPressure    0
# CloudCover          0
# Visibility          0
# SolarRadiation      0
# SolarEnergy         0
# UVIndex             0
# Sunrise             0
# Sunset              0
# MoonPhase           0
# Conditions          0
# Description         0
# Icon                0
# Stations            0
# Label               0
# dtype: int64

# %%
#numerical = df.select_dtypes(exclude=['object'])
#objects = df.select_dtypes(include=['object'])
#numerical
#objects

# %%
#le = preprocessing.LabelEncoder()
#encoded_objects = objects.apply(le.fit_transform)
#df = pd.concat([encoded_objects, numerical], axis=1)
#df

# %%
#x = df.drop(['Label'], axis=1)
#y = df.Label

# %%
humidity = df.Humidity
print(df.columns)
label = df.Label
precipProb = df.PrecipProb
# Out:
# Index(['Name', 'Datetime', 'TempMax', 'TempMin', 'Temp', 'Feelslikemax',
#        'Feelslikemin', 'Feelslike', 'Dew', 'Humidity', 'Precip', 'PrecipProb',
#        'PrecipCover', 'Snow', 'SnowDepth', 'WindSpeed', 'WindDir',
#        'SeaLevelPressure', 'CloudCover', 'Visibility', 'SolarRadiation',
#        'SolarEnergy', 'UVIndex', 'Sunrise', 'Sunset', 'MoonPhase',
#        'Conditions', 'Description', 'Icon', 'Stations', 'Label'],
#       dtype='object')

# %%
#logit_model = sm.Logit(x, y)
#result = logit_model.fit()
#print(result)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
y = []
for i in label:
    y.append(sigmoid(i))

# %%
plt.plot(label, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
humidity
# Out:
# 0      77.7
# 1      58.7
# 2      43.1
# 3      30.8
# 4      29.3
#        ...
# 361    27.5
# 362    24.0
# 363    21.2
# 364    17.8
# 365    22.7
# Name: Humidity, Length: 366, dtype: float64

# %%
y
# Out:
# [0.7310585786300049,
#  0.5,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.7310585786300049,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
# ...

# %%
ax = sns.countplot(x="label", data=data)

# %%
#coeff = list(logreg.coef_[0])
#labels = list(X_train.columns)
#features = pd.DataFrame()
#features['Features'] = labels
#features['importance'] = coeff
#features.sort_values(by=['importance'], ascending=True, inplace=True)
#features['positive'] = features['importance'] > 0
#features.set_index('Features', inplace=True)
#features.importance.plot(kind='barh', figsize=(11, 6),color = features.positive.map({True: 'blue', False: 'red'}))
#plt.xlabel('Importance')

# %%
#plt.scatter(X.Humidity,y) #Trying this has been the best one to
#classes = logreg.classes_
#b0 = logreg.intercept_
#b1 = logreg.coef_[0][1] #coef de humidity
#print(b0)
#print(b1)

# %%
#def sigmoid(x):
 #   return 1 / (1 + np.exp(-x))

# %%
#y = []
#for i in humidity:
 #   y.append(sigmoid(i))

# %%
#plt.plot(humidity, y)
#pOdds = []
#for i in y:
 #   if(i!=1):
  #      pOdds.append(np.log(i/(1-i)))
   # else:
    #    0
#pOdds
#sns.regplot(x=humidity, y=y, logistic = True, ci=None)

# %%
#ax = sns.countplot(x="label", data=data) #Rain vs no rain
#plt.scatter(humidity, label, marker="+", color="red")
